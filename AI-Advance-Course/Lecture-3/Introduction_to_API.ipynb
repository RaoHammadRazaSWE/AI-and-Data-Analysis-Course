# %% [markdown]
# # Lecture 12 Introduction_to_API

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.10.0-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.10.14)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Collecting typing-extensions<5,>=4.7 (from openai)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: typing-extensions, h11, httpcore, httpx, openai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed h11-0.14.0 httpcore-1.0.2 httpx-0.26.0 openai-1.10.0 typing-extensions-4.9.0

# %%
import openai

# %%
openai.api_key = 'PUTKEY'

# %% [markdown]
# # Generating the blog using the open ai api

# %%
def generate_blog(topic):
    messages = [
        {"role": "system", "content": """You are trained to analyze a topic and generate a blog post.
                                        The blog post must contain 1500 to 3000 words (No less than 1500 words)."""},
        {"role": "user", "content": f"""Analyze the topic and generate a blog post. The topic is {topic}
                                        The blog post should contain the following format.
                                        1) Title (Not more than one line).
                                        2) Introduction (Give introducion about the topic)
                                        3) Add an image url relevent to the topic.
                                        4) Add 2/3 subheadings and explain them.
                                        5) Body (should describe the facts and findings)
                                        6) Add an image url relevent to the topic.
                                        7) Add 2/3 subheadings and explain them.
                                        8) General FAQ regarding the topic.
                                        9) Conclusion of the topic. """}
        ]



    response = openai.chat.completions.create(model="gpt-3.5-turbo-16k",
                                              messages=messages,
                                              max_tokens=3000,
                                              n=1,
                                              temperature=0.5)

    response_text = response.choices[0].message.content.strip().lower()

    return response_text

# %%
user_input ="Machine Learning"
blog = generate_blog(user_input)
print(blog)
# Out:
# title: machine learning: unleashing the power of artificial intelligence
#
# introduction:
# machine learning (ml) is a branch of artificial intelligence (ai) that empowers computers to learn and make decisions without explicit programming. it is a rapidly evolving field that has revolutionized various industries, including healthcare, finance, marketing, and more. by analyzing vast amounts of data, ml algorithms can identify patterns, make predictions, and automate tasks, leading to improved efficiency and accuracy. in this blog post, we will delve into the world of machine learning, exploring its key concepts, applications, and potential impact on society.
#
# ![machine learning](https://example.com/machine-learning-image)
#
# subheading 1: supervised learning
# supervised learning is one of the fundamental approaches in machine learning. it involves training a model using labeled data, where the desired output is already known. the model learns from this labeled data and can then predict the output for new, unseen data. for instance, in a spam email detection system, supervised learning algorithms can be trained on a dataset of labeled emails (spam or not spam) to classify future emails accurately.
#
# subheading 2: unsupervised learning
# unsupervised learning is another important aspect of machine learning. unlike supervised learning, unsupervised learning algorithms work with unlabeled data, where the desired output is unknown. the goal is to discover hidden patterns or structures within the data. this approach is often used for tasks such as clustering, anomaly detection, and dimensionality reduction. for example, unsupervised learning can be applied to customer segmentation, grouping similar customers based on their behavior or preferences.
#
# subheading 3: reinforcement learning
# reinforcement learning is a type of machine learning that involves an agent learning from interactions with an environment. the agent receives feedback in the form of rewards or penalties based on its actions, and its objective is to maximize the cumulative reward over time. this approach is commonly used in robotics, gaming, and autonomous systems. for instance, reinforcement learning can be employed to train a robot to navigate a maze, where it receives rewards for finding the correct path and penalties for taking wrong turns.
#
# body:
# machine learning has become an integral part of our daily lives, even if we may not always be aware of it. from personalized recommendations on streaming platforms to voice assistants on our smartphones, ml algorithms are working behind the scenes to enhance our experiences. let's explore some of the key applications of machine learning across various industries:
#
# 1. healthcare:
# machine learning has the potential to revolutionize healthcare by improving diagnostics, treatment plans, and patient outcomes. ml algorithms can analyze medical images, such as x-rays and mri scans, to detect abnormalities and assist radiologists in making accurate diagnoses. additionally, machine learning can be used to predict disease progression, identify high-risk patients, and optimize treatment plans based on individual patient data.
#
# 2. finance:
# in the finance industry, machine learning algorithms are employed for fraud detection, credit scoring, algorithmic trading, and risk assessment. ml models can analyze large volumes of financial data, identify patterns indicative of fraudulent activities, and flag suspicious transactions in real-time. moreover, machine learning can assist in predicting market trends, optimizing investment portfolios, and automating trading strategies.
#
# 3. marketing and advertising:
# machine learning has transformed the way companies target and engage with their customers. by analyzing customer data, ml algorithms can personalize marketing campaigns, recommend products or services based on individual preferences, and optimize pricing strategies. furthermore, machine learning can analyze social media sentiment to gauge public opinion about a brand or product, enabling companies to make data-driven decisions and improve customer satisfaction.
#
# ![machine learning applications](https://example.com/machine-learning-applications-image)
#
# subheading 1: natural language processing (nlp)
# natural language processing is a subfield of machine learning that focuses on the interaction between computers and human language. nlp algorithms enable machines to understand, interpret, and generate human language, enabling applications such as chatbots, language translation, sentiment analysis, and voice recognition. nlp has significant implications for customer service, content generation, and accessibility.
#
# subheading 2: computer vision
# computer vision is another subfield of machine learning that enables computers to understand and interpret visual information from images or videos. ml algorithms can analyze images to detect objects, recognize faces, and classify scenes. this technology has numerous applications, including autonomous vehicles, surveillance systems, medical imaging, and augmented reality. computer vision has the potential to revolutionize various industries, improving safety, efficiency, and decision-making processes.
#
# subheading 3: deep learning
# deep learning is a subset of machine learning that focuses on artificial neural networks with multiple layers. these deep neural networks can automatically learn hierarchical representations of data, enabling them to handle complex tasks such as image recognition, natural language processing, and speech synthesis. deep learning has achieved remarkable success in recent years, breaking records in various domains, including image classification, speech recognition, and game playing.
#
# general faq regarding machine learning:
#
# q: what is the difference between machine learning and artificial intelligence?
# a: machine learning is a subset of artificial intelligence. while ai encompasses a broader range of concepts and techniques, machine learning specifically focuses on algorithms that enable computers to learn from data and make predictions or decisions without explicit programming.
#
# q: what are the prerequisites for getting started with machine learning?
# a: basic knowledge of programming (python is commonly used), statistics, and linear algebra is beneficial for understanding and implementing machine learning algorithms. additionally, familiarity with libraries such as scikit-learn and tensorflow can expedite the development process.
#
# q: is machine learning only applicable to large datasets?
# a: while machine learning algorithms can benefit from large datasets, they can also be effective with smaller datasets. the performance of ml models depends on the quality and diversity of the data rather than just the quantity.
#
# conclusion:
# machine learning has emerged as a powerful tool that has the potential to transform industries and improve various aspects of our lives. from healthcare to finance, marketing to robotics, ml algorithms are driving innovation and enabling us to tackle complex problems more efficiently. as technology continues to advance, the possibilities for machine learning applications are seemingly endless. however, it is essential to ensure responsible and ethical use of machine learning to address potential challenges and concerns. by harnessing the power of machine learning, we can unlock new opportunities and pave the way for a future powered by artificial intelligence.

# %%
def Senitment_analysis(text):
    messages = [
        {"role": "system", "content": """You are trained to analyze and detect the sentiment of given text.
                                        If you're unsure of an answer, you can say "not sure" and recommend users to review manually."""},
        {"role": "user", "content": f"""Analyze the following text and determine if the sentiment is: positive or negative.
                                        Return answer in single word as either positive or negative: {text}"""}
        ]



    response = openai.chat.completions.create(model= "gpt-3.5-turbo-16k",
                                              messages=messages,
                                              max_tokens=1,
                                              n=1,
                                              temperature=0)

    response_text = response.choices[0].message.content.strip().lower()


    return response_text

# %%
# Calling the function
input = 'I hate fast food'
response = Senitment_analysis(input)
print(input,': The Sentiment is', response)
# Out:
# I hate fast food : The Sentiment is negative

# %%
def CountryProblemAnalysis(country_name):
  messages = [
      { "role ": "system" , "content": """ You are trained to analyze and detect the problems associated with a given country.

             If you're unsure of an answer, you can say "not sure" and recommend users to review manually."""
      },
      { "role": "user" , "content": f"""Analyze the problems associated with the following country: {country_name}
             Return the analysis in a sentence or a few words."""

      }
  ]
  response = openai.ChatCompletions.create(model= "gpt-3.5-turbo-16k",
                                              messages=messages,
                                              max_tokens=100,
                                              n=1,
                                              temperature=0.7)

  response_text = response.choices[0].message.content.strip().lower()

  return response_text

# %%
openai.api_key = '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'

# %%
# Calling the function
country_name = "Pakistan"
response = CountryProblemAnalysis(country_name)
print(f"The analysis of problems in {country_name} is: {response}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-84c20678549d> in <cell line: 3>()
#       1 # Calling the function
#       2 country_name = "Pakistan"
# ----> 3 response = CountryProblemAnalysis(country_name)
#       4 print(f"The analysis of problems in {country_name} is: {response}")
#
# <ipython-input-20-4631036ae165> in CountryProblemAnalysis(country_name)
#      10       }
#      11   ]
# ---> 12   response = openai.ChatCompletions.create(model= "gpt-3.5-turbo-16k",
#      13                                               messages=messages,
#      14                                               max_tokens=100,
#
# AttributeError: module 'openai' has no attribute 'ChatCompletions'
