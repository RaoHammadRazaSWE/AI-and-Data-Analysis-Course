# %% [markdown]
# Auto Encoders
#
# You will Learn the following
#
# Loading dataset
#
# Preprocessing the dataset
#
# Architecture of Vanilla Auto-encoders using CNN
#
# Generating the image from Auto encoders
#
# Denoising Auto Encoders

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Dataset

# %%
# Loading the dataset without Target Variables
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# Display the Loaded dataset sample images


n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), 28*28*1))
x_test = x_test.reshape((len(x_test), 28*28*1))
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# Auto Encoder using ANN

# %% [markdown]
# Preprocessing of Dataset

# %% [markdown]
# Developing Encoder, Decode and Autoencoder Models

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# %%
input_img = Input(shape=(784,))  #Input layer
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(28, activation='relu')(encoded)

encoded = Dense(20, activation='relu', name='bot')(encoded)

decoded = Dense(28, activation='relu', name='botnext0')(encoded)
decoded = Dense(64, activation='relu', name='botnext1')(decoded)
decoded = Dense(128, activation='relu', name = 'botnext2')(decoded)
decoded = Dense(784, activation='sigmoid', name="ae_out")(decoded)

Autoencoder = Model(inputs=input_img, outputs=decoded)
Autoencoder.compile(optimizer=tf.keras.optimizers.SGD(0.09,clipvalue=2.5), loss='binary_crossentropy')#, metrics = ["accuracy"])
Autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 28)                1820
#
#  bot (Dense)                 (None, 20)                580
#
#  botnext0 (Dense)            (None, 28)                588
#
#  botnext1 (Dense)            (None, 64)                1856
#
#  botnext2 (Dense)            (None, 128)               8320
#
#  ae_out (Dense)              (None, 784)               101136
#
# =================================================================
# Total params: 223036 (871.23 KB)
# Trainable params: 223036 (871.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Encoder Model
encoder_vn = Model(inputs = input_img, outputs= Autoencoder.get_layer("bot").output )
encoder_vn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 28)                1820
#
#  bot (Dense)                 (None, 20)                580
#
# =================================================================
# Total params: 111136 (434.12 KB)
# Trainable params: 111136 (434.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Double-click (or enter) to edit

# %%
encoded_input = Input(shape=(20,))
d_layer = Autoencoder.get_layer("botnext0")(encoded_input)
d_layer = Autoencoder.get_layer("botnext1")(d_layer)
d_layer = Autoencoder.get_layer("botnext2")(d_layer)
d_layer = Autoencoder.get_layer("ae_out")(d_layer)
decoder_vn = Model(inputs = encoded_input , outputs = d_layer)
decoder_vn.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20)]              0
#
#  botnext0 (Dense)            (None, 28)                588
#
#  botnext1 (Dense)            (None, 64)                1856
#
#  botnext2 (Dense)            (None, 128)               8320
#
#  ae_out (Dense)              (None, 784)               101136
#
# =================================================================
# Total params: 111900 (437.11 KB)
# Trainable params: 111900 (437.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
Autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 28)                1820
#
#  bot (Dense)                 (None, 20)                580
#
#  botnext0 (Dense)            (None, 28)                588
#
#  botnext1 (Dense)            (None, 64)                1856
#
#  botnext2 (Dense)            (None, 128)               8320
#
#  ae_out (Dense)              (None, 784)               101136
#
# =================================================================
# Total params: 223036 (871.23 KB)
# Trainable params: 223036 (871.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from time import time
tic = time()
Autoencoder.fit(x_train, x_train,
                epochs=100,
                verbose=2,
                batch_size=1024,
                shuffle=True, validation_split = 0.1)
                #validation_data=(x_test, x_test))
toc = time()
print("Training Took {} Secs".format(toc-tic))
# Out:
# Epoch 1/100
# 53/53 - 9s - loss: 0.6924 - val_loss: 0.6918 - 9s/epoch - 161ms/step
# Epoch 2/100
# 53/53 - 0s - loss: 0.6911 - val_loss: 0.6905 - 499ms/epoch - 9ms/step
# Epoch 3/100
# 53/53 - 0s - loss: 0.6898 - val_loss: 0.6891 - 489ms/epoch - 9ms/step
# Epoch 4/100
# 53/53 - 1s - loss: 0.6884 - val_loss: 0.6876 - 503ms/epoch - 9ms/step
# Epoch 5/100
# 53/53 - 0s - loss: 0.6868 - val_loss: 0.6859 - 483ms/epoch - 9ms/step
# Epoch 6/100
# 53/53 - 1s - loss: 0.6849 - val_loss: 0.6837 - 502ms/epoch - 9ms/step
# Epoch 7/100
# 53/53 - 0s - loss: 0.6824 - val_loss: 0.6807 - 490ms/epoch - 9ms/step
# Epoch 8/100
# 53/53 - 0s - loss: 0.6785 - val_loss: 0.6755 - 487ms/epoch - 9ms/step
# Epoch 9/100
# 53/53 - 1s - loss: 0.6701 - val_loss: 0.6617 - 547ms/epoch - 10ms/step
# Epoch 10/100
# 53/53 - 1s - loss: 0.6366 - val_loss: 0.5845 - 640ms/epoch - 12ms/step
# Epoch 11/100
# 53/53 - 1s - loss: 0.4617 - val_loss: 0.3350 - 671ms/epoch - 13ms/step
# Epoch 12/100
# 53/53 - 1s - loss: 0.3001 - val_loss: 0.2830 - 553ms/epoch - 10ms/step
# Epoch 13/100
# 53/53 - 1s - loss: 0.2797 - val_loss: 0.2758 - 577ms/epoch - 11ms/step
# Epoch 14/100
# 53/53 - 1s - loss: 0.2750 - val_loss: 0.2728 - 558ms/epoch - 11ms/step
# Epoch 15/100
# 53/53 - 1s - loss: 0.2726 - val_loss: 0.2709 - 544ms/epoch - 10ms/step
# Epoch 16/100
# 53/53 - 0s - loss: 0.2710 - val_loss: 0.2695 - 397ms/epoch - 7ms/step
# Epoch 17/100
# 53/53 - 0s - loss: 0.2698 - val_loss: 0.2684 - 417ms/epoch - 8ms/step
# Epoch 18/100
# 53/53 - 0s - loss: 0.2687 - val_loss: 0.2675 - 385ms/epoch - 7ms/step
# Epoch 19/100
# 53/53 - 0s - loss: 0.2679 - val_loss: 0.2667 - 409ms/epoch - 8ms/step
# Epoch 20/100
# 53/53 - 0s - loss: 0.2671 - val_loss: 0.2660 - 426ms/epoch - 8ms/step
# Epoch 21/100
# 53/53 - 0s - loss: 0.2665 - val_loss: 0.2654 - 425ms/epoch - 8ms/step
# Epoch 22/100
# 53/53 - 0s - loss: 0.2659 - val_loss: 0.2648 - 423ms/epoch - 8ms/step
# Epoch 23/100
# 53/53 - 0s - loss: 0.2654 - val_loss: 0.2643 - 390ms/epoch - 7ms/step
# Epoch 24/100
# 53/53 - 0s - loss: 0.2649 - val_loss: 0.2639 - 419ms/epoch - 8ms/step
# Epoch 25/100
# 53/53 - 0s - loss: 0.2645 - val_loss: 0.2635 - 391ms/epoch - 7ms/step
# Epoch 26/100
# 53/53 - 0s - loss: 0.2641 - val_loss: 0.2631 - 435ms/epoch - 8ms/step
# Epoch 27/100
# 53/53 - 0s - loss: 0.2637 - val_loss: 0.2627 - 390ms/epoch - 7ms/step
# Epoch 28/100
# 53/53 - 1s - loss: 0.2633 - val_loss: 0.2624 - 513ms/epoch - 10ms/step
# Epoch 29/100
# 53/53 - 0s - loss: 0.2629 - val_loss: 0.2620 - 474ms/epoch - 9ms/step
# Epoch 30/100
# 53/53 - 0s - loss: 0.2626 - val_loss: 0.2616 - 492ms/epoch - 9ms/step
# Epoch 31/100
# 53/53 - 0s - loss: 0.2622 - val_loss: 0.2613 - 470ms/epoch - 9ms/step
# Epoch 32/100
# 53/53 - 1s - loss: 0.2619 - val_loss: 0.2610 - 514ms/epoch - 10ms/step
# Epoch 33/100
# 53/53 - 0s - loss: 0.2615 - val_loss: 0.2606 - 488ms/epoch - 9ms/step
# Epoch 34/100
# 53/53 - 0s - loss: 0.2612 - val_loss: 0.2603 - 489ms/epoch - 9ms/step
# Epoch 35/100
# 53/53 - 0s - loss: 0.2608 - val_loss: 0.2600 - 460ms/epoch - 9ms/step
# Epoch 36/100
# 53/53 - 0s - loss: 0.2605 - val_loss: 0.2597 - 477ms/epoch - 9ms/step
# Epoch 37/100
# 53/53 - 1s - loss: 0.2602 - val_loss: 0.2594 - 522ms/epoch - 10ms/step
# Epoch 38/100
# 53/53 - 1s - loss: 0.2598 - val_loss: 0.2590 - 665ms/epoch - 13ms/step
# Epoch 39/100
# 53/53 - 1s - loss: 0.2595 - val_loss: 0.2587 - 689ms/epoch - 13ms/step
# Epoch 40/100
# 53/53 - 1s - loss: 0.2592 - val_loss: 0.2584 - 687ms/epoch - 13ms/step
# Epoch 41/100
# 53/53 - 1s - loss: 0.2589 - val_loss: 0.2581 - 635ms/epoch - 12ms/step
# Epoch 42/100
# 53/53 - 1s - loss: 0.2586 - val_loss: 0.2577 - 655ms/epoch - 12ms/step
# Epoch 43/100
# 53/53 - 1s - loss: 0.2582 - val_loss: 0.2575 - 616ms/epoch - 12ms/step
# Epoch 44/100
# 53/53 - 0s - loss: 0.2579 - val_loss: 0.2572 - 476ms/epoch - 9ms/step
# Epoch 45/100
# 53/53 - 0s - loss: 0.2576 - val_loss: 0.2569 - 468ms/epoch - 9ms/step
# Epoch 46/100
# 53/53 - 0s - loss: 0.2574 - val_loss: 0.2566 - 482ms/epoch - 9ms/step
# Epoch 47/100
# 53/53 - 1s - loss: 0.2571 - val_loss: 0.2564 - 519ms/epoch - 10ms/step
# Epoch 48/100
# 53/53 - 0s - loss: 0.2568 - val_loss: 0.2561 - 474ms/epoch - 9ms/step
# Epoch 49/100
# 53/53 - 1s - loss: 0.2565 - val_loss: 0.2559 - 522ms/epoch - 10ms/step
# Epoch 50/100
# 53/53 - 0s - loss: 0.2563 - val_loss: 0.2556 - 486ms/epoch - 9ms/step
# Epoch 51/100
# 53/53 - 0s - loss: 0.2560 - val_loss: 0.2554 - 496ms/epoch - 9ms/step
# Epoch 52/100
# 53/53 - 1s - loss: 0.2558 - val_loss: 0.2552 - 501ms/epoch - 9ms/step
# Epoch 53/100
# 53/53 - 0s - loss: 0.2555 - val_loss: 0.2550 - 484ms/epoch - 9ms/step
# Epoch 54/100
# 53/53 - 0s - loss: 0.2553 - val_loss: 0.2547 - 467ms/epoch - 9ms/step
# Epoch 55/100
# 53/53 - 0s - loss: 0.2551 - val_loss: 0.2545 - 499ms/epoch - 9ms/step
# Epoch 56/100
# 53/53 - 0s - loss: 0.2549 - val_loss: 0.2543 - 438ms/epoch - 8ms/step
# Epoch 57/100
# 53/53 - 1s - loss: 0.2547 - val_loss: 0.2542 - 518ms/epoch - 10ms/step
# Epoch 58/100
# 53/53 - 0s - loss: 0.2545 - val_loss: 0.2540 - 483ms/epoch - 9ms/step
# Epoch 59/100
# 53/53 - 0s - loss: 0.2543 - val_loss: 0.2538 - 493ms/epoch - 9ms/step
# Epoch 60/100
# 53/53 - 1s - loss: 0.2542 - val_loss: 0.2537 - 520ms/epoch - 10ms/step
# Epoch 61/100
# 53/53 - 0s - loss: 0.2540 - val_loss: 0.2535 - 451ms/epoch - 9ms/step
# Epoch 62/100
# 53/53 - 1s - loss: 0.2538 - val_loss: 0.2533 - 642ms/epoch - 12ms/step
# Epoch 63/100
# 53/53 - 1s - loss: 0.2537 - val_loss: 0.2532 - 855ms/epoch - 16ms/step
# Epoch 64/100
# 53/53 - 1s - loss: 0.2535 - val_loss: 0.2531 - 1s/epoch - 20ms/step
# Epoch 65/100
# 53/53 - 1s - loss: 0.2534 - val_loss: 0.2530 - 893ms/epoch - 17ms/step
# Epoch 66/100
# 53/53 - 1s - loss: 0.2533 - val_loss: 0.2529 - 645ms/epoch - 12ms/step
# Epoch 67/100
# 53/53 - 1s - loss: 0.2531 - val_loss: 0.2527 - 658ms/epoch - 12ms/step
# Epoch 68/100
# 53/53 - 1s - loss: 0.2530 - val_loss: 0.2526 - 533ms/epoch - 10ms/step
# Epoch 69/100
# 53/53 - 0s - loss: 0.2529 - val_loss: 0.2525 - 445ms/epoch - 8ms/step
# Epoch 70/100
# 53/53 - 0s - loss: 0.2528 - val_loss: 0.2524 - 446ms/epoch - 8ms/step
# Epoch 71/100
# 53/53 - 0s - loss: 0.2527 - val_loss: 0.2523 - 483ms/epoch - 9ms/step
# Epoch 72/100
# 53/53 - 0s - loss: 0.2526 - val_loss: 0.2523 - 455ms/epoch - 9ms/step
# Epoch 73/100
# 53/53 - 0s - loss: 0.2525 - val_loss: 0.2521 - 498ms/epoch - 9ms/step
# Epoch 74/100
# 53/53 - 0s - loss: 0.2524 - val_loss: 0.2520 - 483ms/epoch - 9ms/step
# Epoch 75/100
# 53/53 - 0s - loss: 0.2523 - val_loss: 0.2519 - 484ms/epoch - 9ms/step
# Epoch 76/100
# 53/53 - 0s - loss: 0.2522 - val_loss: 0.2519 - 453ms/epoch - 9ms/step
# Epoch 77/100
# 53/53 - 0s - loss: 0.2521 - val_loss: 0.2518 - 472ms/epoch - 9ms/step
# Epoch 78/100
# 53/53 - 0s - loss: 0.2520 - val_loss: 0.2517 - 437ms/epoch - 8ms/step
# Epoch 79/100
# 53/53 - 0s - loss: 0.2520 - val_loss: 0.2517 - 486ms/epoch - 9ms/step
# Epoch 80/100
# 53/53 - 1s - loss: 0.2519 - val_loss: 0.2516 - 531ms/epoch - 10ms/step
# Epoch 81/100
# 53/53 - 0s - loss: 0.2518 - val_loss: 0.2515 - 458ms/epoch - 9ms/step
# Epoch 82/100
# 53/53 - 0s - loss: 0.2517 - val_loss: 0.2514 - 394ms/epoch - 7ms/step
# Epoch 83/100
# 53/53 - 0s - loss: 0.2517 - val_loss: 0.2514 - 438ms/epoch - 8ms/step
# Epoch 84/100
# 53/53 - 0s - loss: 0.2516 - val_loss: 0.2513 - 408ms/epoch - 8ms/step
# Epoch 85/100
# 53/53 - 0s - loss: 0.2515 - val_loss: 0.2513 - 391ms/epoch - 7ms/step
# Epoch 86/100
# 53/53 - 0s - loss: 0.2515 - val_loss: 0.2512 - 407ms/epoch - 8ms/step
# Epoch 87/100
# 53/53 - 0s - loss: 0.2514 - val_loss: 0.2512 - 426ms/epoch - 8ms/step
# Epoch 88/100
# 53/53 - 0s - loss: 0.2514 - val_loss: 0.2511 - 386ms/epoch - 7ms/step
# Epoch 89/100
# 53/53 - 0s - loss: 0.2513 - val_loss: 0.2511 - 395ms/epoch - 7ms/step
# Epoch 90/100
# 53/53 - 1s - loss: 0.2512 - val_loss: 0.2510 - 501ms/epoch - 9ms/step
# Epoch 91/100
# 53/53 - 1s - loss: 0.2512 - val_loss: 0.2509 - 579ms/epoch - 11ms/step
# Epoch 92/100
# 53/53 - 1s - loss: 0.2511 - val_loss: 0.2509 - 547ms/epoch - 10ms/step
# Epoch 93/100
# 53/53 - 1s - loss: 0.2511 - val_loss: 0.2508 - 575ms/epoch - 11ms/step
# Epoch 94/100
# 53/53 - 1s - loss: 0.2510 - val_loss: 0.2508 - 529ms/epoch - 10ms/step
# Epoch 95/100
# 53/53 - 1s - loss: 0.2510 - val_loss: 0.2507 - 562ms/epoch - 11ms/step
# Epoch 96/100
# 53/53 - 1s - loss: 0.2509 - val_loss: 0.2507 - 565ms/epoch - 11ms/step
# Epoch 97/100
# 53/53 - 0s - loss: 0.2509 - val_loss: 0.2506 - 412ms/epoch - 8ms/step
# Epoch 98/100
# 53/53 - 0s - loss: 0.2508 - val_loss: 0.2506 - 419ms/epoch - 8ms/step
# Epoch 99/100
# 53/53 - 0s - loss: 0.2508 - val_loss: 0.2505 - 436ms/epoch - 8ms/step
# Epoch 100/100
# 53/53 - 0s - loss: 0.2507 - val_loss: 0.2505 - 419ms/epoch - 8ms/step
# Training Took 60.194459199905396 Secs

# %%
#encoded_imgs = encoder_l.predict(x_test)
encoded_imgs = encoder_vn.predict(x_test)
print("Reduced Image Representation shape achieved Through Encoder Part: {}".format(encoded_imgs.shape))
#decoded_imgs = decoder_l.predict(encoded_imgs)
decoded_imgs = decoder_vn.predict(encoded_imgs)
print("Recreated image Representation of Shape {} using Decoder and reduced Image representation of shape {}".format (decoded_imgs.shape, encoded_imgs.shape))
n = 10  # how many digits we will display
k = 9 #multiplier
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i*k].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i*k].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Reduced Image Representation shape achieved Through Encoder Part: (10000, 20)
# 313/313 [==============================] - 1s 2ms/step
# Recreated image Representation of Shape (10000, 784) using Decoder and reduced Image representation of shape (10000, 20)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
from tensorflow.keras.models import Model

# %% [markdown]
# Architecture of Auto-encoder

# %%
input_layer_cnv = Input(shape = (28,28,1))
ae_cnv_en = Conv2D (32, (3,3), activation = "relu", padding = "same", kernel_initializer="he_normal")(input_layer_cnv)
ae_cnv_en = MaxPooling2D ((2,2), padding="same")(ae_cnv_en)

ae_cnv_en = Conv2D (32, (3,3), activation = "relu", padding = "same")(ae_cnv_en)
ae_cnv_en = MaxPooling2D ((2,2), padding="same")(ae_cnv_en)

ae_cnv_en = Conv2D (4, (3,3), activation = "relu", padding = "same")(ae_cnv_en)
ae_cnv_en = MaxPooling2D ((2,2), padding="same")(ae_cnv_en)

ae_cnv_en = Flatten(name = "bot")(ae_cnv_en)

ae_cnv_de = Reshape((4,4,4), input_shape= (64,), name= "botnext0")(ae_cnv_en)
ae_cnv_de = Conv2D (4, (3,3), activation = "relu", padding = "same",name= "botnext1")(ae_cnv_de)
ae_cnv_de = UpSampling2D ((2,2),name= "botnext2")(ae_cnv_de)

ae_cnv_de = Conv2D (32, (3,3), activation = "relu", padding = "same", name= "botnext3")(ae_cnv_de)
ae_cnv_de = UpSampling2D ((2,2), name= "botnext4")(ae_cnv_de)

ae_cnv_de = Conv2D (32, (3,3), activation = "relu", padding = "valid",name= "botnext5")(ae_cnv_de)
ae_cnv_de = UpSampling2D ((2,2), name= "botnext6")(ae_cnv_de)

ae_cnv_de = Conv2D (1, (3,3), activation = "sigmoid", padding = "same",name = "botnext7")(ae_cnv_de)
Ae_Conv = Model(inputs = input_layer_cnv, outputs = ae_cnv_de)

Ae_Conv.compile(optimizer=tf.keras.optimizers.SGD(0.09,clipvalue=2.5), loss='binary_crossentropy', metrics = ["accuracy"])
# Ae_Conv.compile(optimizer=tf.keras.optimizers.Adadelta(0.1,clipvalue=2), loss='binary_crossentropy', metrics = ["accuracy"])
Ae_Conv.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 4)           1156
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 4)           0
#  g2D)
#
#  bot (Flatten)               (None, 64)                0
#
#  botnext0 (Reshape)          (None, 4, 4, 4)           0
#
#  botnext1 (Conv2D)           (None, 4, 4, 4)           148
#
#  botnext2 (UpSampling2D)     (None, 8, 8, 4)           0
#
#  botnext3 (Conv2D)           (None, 8, 8, 32)          1184
#
#  botnext4 (UpSampling2D)     (None, 16, 16, 32)        0
#
#  botnext5 (Conv2D)           (None, 14, 14, 32)        9248
#
#  botnext6 (UpSampling2D)     (None, 28, 28, 32)        0
#
#  botnext7 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 21593 (84.35 KB)
# Trainable params: 21593 (84.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Encoder

# %%
ae_conv_encoder = Model (inputs = input_layer_cnv, outputs = Ae_Conv.get_layer("bot").output, name = "Conv_AE_encoder")
ae_conv_encoder.summary()
# Out:
# Model: "Conv_AE_encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 4)           1156
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 4)           0
#  g2D)
#
#  bot (Flatten)               (None, 64)                0
#
# =================================================================
# Total params: 10724 (41.89 KB)
# Trainable params: 10724 (41.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Decoder

# %%
# Traversing through the Layers of Decoder using Loop

encode_inp_cnv = Input(shape = (64,))
tmp_dec = Ae_Conv.get_layer("botnext0")(encode_inp_cnv)
for i in range(1,8):
  st = "botnext{}".format(i)
  tmp_dec = Ae_Conv.get_layer(st)(tmp_dec)

ae_conv_decoder = Model(inputs = encode_inp_cnv, outputs = tmp_dec, name= "Conv_AE_decoder")
ae_conv_decoder.summary()
# Out:
# Model: "Conv_AE_decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 64)]              0
#
#  botnext0 (Reshape)          (None, 4, 4, 4)           0
#
#  botnext1 (Conv2D)           (None, 4, 4, 4)           148
#
#  botnext2 (UpSampling2D)     (None, 8, 8, 4)           0
#
#  botnext3 (Conv2D)           (None, 8, 8, 32)          1184
#
#  botnext4 (UpSampling2D)     (None, 16, 16, 32)        0
#
#  botnext5 (Conv2D)           (None, 14, 14, 32)        9248
#
#  botnext6 (UpSampling2D)     (None, 28, 28, 32)        0
#
#  botnext7 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 10869 (42.46 KB)
# Trainable params: 10869 (42.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Reshapping the Data

# %%
x_train = x_train.reshape(x_train.shape[0], 28,28,1)
x_test = x_test.reshape(x_test.shape[0], 28,28,1)
print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %% [markdown]
# Training the Auto Encoders

# %%
from time import time
tic = time()
Ae_Conv.fit(x_train, x_train,
                epochs=100,
                verbose=2,
                batch_size=1024,
                shuffle=False, validation_split = 0.1)
                #validation_data=(x_test, x_test))
toc = time()
print("Training Took {} Secs".format(toc-tic))
# Out:
# Epoch 1/100
# 53/53 - 10s - loss: 0.3830 - accuracy: 0.8032 - val_loss: 0.2937 - val_accuracy: 0.8088 - 10s/epoch - 197ms/step
# Epoch 2/100
# 53/53 - 2s - loss: 0.2616 - accuracy: 0.8045 - val_loss: 0.2421 - val_accuracy: 0.8063 - 2s/epoch - 31ms/step
# Epoch 3/100
# 53/53 - 2s - loss: 0.2330 - accuracy: 0.7932 - val_loss: 0.2256 - val_accuracy: 0.7952 - 2s/epoch - 32ms/step
# Epoch 4/100
# 53/53 - 2s - loss: 0.2198 - accuracy: 0.7918 - val_loss: 0.2186 - val_accuracy: 0.8049 - 2s/epoch - 34ms/step
# Epoch 5/100
# 53/53 - 2s - loss: 0.2107 - accuracy: 0.7909 - val_loss: 0.2045 - val_accuracy: 0.7883 - 2s/epoch - 34ms/step
# Epoch 6/100
# 53/53 - 2s - loss: 0.2042 - accuracy: 0.7900 - val_loss: 0.2036 - val_accuracy: 0.8017 - 2s/epoch - 32ms/step
# Epoch 7/100
# 53/53 - 2s - loss: 0.1986 - accuracy: 0.7905 - val_loss: 0.1976 - val_accuracy: 0.7877 - 2s/epoch - 32ms/step
# Epoch 8/100
# 53/53 - 2s - loss: 0.1952 - accuracy: 0.7909 - val_loss: 0.1948 - val_accuracy: 0.8001 - 2s/epoch - 32ms/step
# Epoch 9/100
# 53/53 - 2s - loss: 0.1913 - accuracy: 0.7916 - val_loss: 0.1903 - val_accuracy: 0.7893 - 2s/epoch - 31ms/step
# Epoch 10/100
# 53/53 - 2s - loss: 0.1889 - accuracy: 0.7922 - val_loss: 0.1886 - val_accuracy: 0.8006 - 2s/epoch - 33ms/step
# Epoch 11/100
# 53/53 - 2s - loss: 0.1857 - accuracy: 0.7930 - val_loss: 0.1835 - val_accuracy: 0.7915 - 2s/epoch - 32ms/step
# Epoch 12/100
# 53/53 - 2s - loss: 0.1834 - accuracy: 0.7936 - val_loss: 0.1832 - val_accuracy: 0.8017 - 2s/epoch - 33ms/step
# Epoch 13/100
# 53/53 - 2s - loss: 0.1806 - accuracy: 0.7944 - val_loss: 0.1780 - val_accuracy: 0.7929 - 2s/epoch - 34ms/step
# Epoch 14/100
# 53/53 - 2s - loss: 0.1786 - accuracy: 0.7948 - val_loss: 0.1789 - val_accuracy: 0.8029 - 2s/epoch - 31ms/step
# Epoch 15/100
# 53/53 - 2s - loss: 0.1762 - accuracy: 0.7956 - val_loss: 0.1734 - val_accuracy: 0.7942 - 2s/epoch - 32ms/step
# Epoch 16/100
# 53/53 - 2s - loss: 0.1744 - accuracy: 0.7959 - val_loss: 0.1751 - val_accuracy: 0.8039 - 2s/epoch - 31ms/step
# Epoch 17/100
# 53/53 - 2s - loss: 0.1723 - accuracy: 0.7966 - val_loss: 0.1697 - val_accuracy: 0.7950 - 2s/epoch - 30ms/step
# Epoch 18/100
# 53/53 - 2s - loss: 0.1708 - accuracy: 0.7968 - val_loss: 0.1716 - val_accuracy: 0.8044 - 2s/epoch - 32ms/step
# Epoch 19/100
# 53/53 - 2s - loss: 0.1689 - accuracy: 0.7974 - val_loss: 0.1664 - val_accuracy: 0.7958 - 2s/epoch - 30ms/step
# Epoch 20/100
# 53/53 - 2s - loss: 0.1675 - accuracy: 0.7976 - val_loss: 0.1684 - val_accuracy: 0.8048 - 2s/epoch - 31ms/step
# Epoch 21/100
# 53/53 - 2s - loss: 0.1657 - accuracy: 0.7982 - val_loss: 0.1637 - val_accuracy: 0.7964 - 2s/epoch - 33ms/step
# Epoch 22/100
# 53/53 - 2s - loss: 0.1645 - accuracy: 0.7983 - val_loss: 0.1654 - val_accuracy: 0.8051 - 2s/epoch - 32ms/step
# Epoch 23/100
# 53/53 - 2s - loss: 0.1628 - accuracy: 0.7988 - val_loss: 0.1615 - val_accuracy: 0.7968 - 2s/epoch - 30ms/step
# Epoch 24/100
# 53/53 - 2s - loss: 0.1619 - accuracy: 0.7989 - val_loss: 0.1627 - val_accuracy: 0.8054 - 2s/epoch - 32ms/step
# Epoch 25/100
# 53/53 - 2s - loss: 0.1602 - accuracy: 0.7994 - val_loss: 0.1589 - val_accuracy: 0.7973 - 2s/epoch - 30ms/step
# Epoch 26/100
# 53/53 - 2s - loss: 0.1595 - accuracy: 0.7995 - val_loss: 0.1607 - val_accuracy: 0.8058 - 2s/epoch - 32ms/step
# Epoch 27/100
# 53/53 - 2s - loss: 0.1579 - accuracy: 0.7999 - val_loss: 0.1567 - val_accuracy: 0.7979 - 2s/epoch - 32ms/step
# Epoch 28/100
# 53/53 - 2s - loss: 0.1573 - accuracy: 0.8000 - val_loss: 0.1583 - val_accuracy: 0.8060 - 2s/epoch - 33ms/step
# Epoch 29/100
# 53/53 - 2s - loss: 0.1558 - accuracy: 0.8004 - val_loss: 0.1550 - val_accuracy: 0.7981 - 2s/epoch - 33ms/step
# Epoch 30/100
# 53/53 - 2s - loss: 0.1554 - accuracy: 0.8004 - val_loss: 0.1565 - val_accuracy: 0.8063 - 2s/epoch - 31ms/step
# Epoch 31/100
# 53/53 - 2s - loss: 0.1539 - accuracy: 0.8008 - val_loss: 0.1533 - val_accuracy: 0.7985 - 2s/epoch - 32ms/step
# Epoch 32/100
# 53/53 - 2s - loss: 0.1535 - accuracy: 0.8008 - val_loss: 0.1548 - val_accuracy: 0.8066 - 2s/epoch - 30ms/step
# Epoch 33/100
# 53/53 - 2s - loss: 0.1520 - accuracy: 0.8012 - val_loss: 0.1515 - val_accuracy: 0.7988 - 2s/epoch - 30ms/step
# Epoch 34/100
# 53/53 - 2s - loss: 0.1519 - accuracy: 0.8012 - val_loss: 0.1531 - val_accuracy: 0.8068 - 2s/epoch - 31ms/step
# Epoch 35/100
# 53/53 - 2s - loss: 0.1503 - accuracy: 0.8016 - val_loss: 0.1497 - val_accuracy: 0.7993 - 2s/epoch - 33ms/step
# Epoch 36/100
# 53/53 - 2s - loss: 0.1502 - accuracy: 0.8015 - val_loss: 0.1515 - val_accuracy: 0.8070 - 2s/epoch - 34ms/step
# Epoch 37/100
# 53/53 - 2s - loss: 0.1487 - accuracy: 0.8020 - val_loss: 0.1479 - val_accuracy: 0.7999 - 2s/epoch - 43ms/step
# Epoch 38/100
# 53/53 - 2s - loss: 0.1487 - accuracy: 0.8019 - val_loss: 0.1498 - val_accuracy: 0.8072 - 2s/epoch - 36ms/step
# Epoch 39/100
# 53/53 - 2s - loss: 0.1473 - accuracy: 0.8023 - val_loss: 0.1462 - val_accuracy: 0.8005 - 2s/epoch - 35ms/step
# Epoch 40/100
# 53/53 - 2s - loss: 0.1473 - accuracy: 0.8022 - val_loss: 0.1482 - val_accuracy: 0.8073 - 2s/epoch - 30ms/step
# Epoch 41/100
# 53/53 - 2s - loss: 0.1459 - accuracy: 0.8026 - val_loss: 0.1446 - val_accuracy: 0.8011 - 2s/epoch - 30ms/step
# Epoch 42/100
# 53/53 - 2s - loss: 0.1459 - accuracy: 0.8025 - val_loss: 0.1468 - val_accuracy: 0.8075 - 2s/epoch - 30ms/step
# Epoch 43/100
# 53/53 - 2s - loss: 0.1446 - accuracy: 0.8029 - val_loss: 0.1432 - val_accuracy: 0.8016 - 2s/epoch - 31ms/step
# Epoch 44/100
# 53/53 - 2s - loss: 0.1447 - accuracy: 0.8028 - val_loss: 0.1455 - val_accuracy: 0.8076 - 2s/epoch - 33ms/step
# Epoch 45/100
# 53/53 - 2s - loss: 0.1434 - accuracy: 0.8032 - val_loss: 0.1419 - val_accuracy: 0.8019 - 2s/epoch - 33ms/step
# Epoch 46/100
# 53/53 - 2s - loss: 0.1435 - accuracy: 0.8031 - val_loss: 0.1443 - val_accuracy: 0.8078 - 2s/epoch - 31ms/step
# Epoch 47/100
# 53/53 - 2s - loss: 0.1423 - accuracy: 0.8034 - val_loss: 0.1406 - val_accuracy: 0.8023 - 2s/epoch - 30ms/step
# Epoch 48/100
# 53/53 - 2s - loss: 0.1424 - accuracy: 0.8034 - val_loss: 0.1433 - val_accuracy: 0.8080 - 2s/epoch - 32ms/step
# Epoch 49/100
# 53/53 - 2s - loss: 0.1412 - accuracy: 0.8037 - val_loss: 0.1396 - val_accuracy: 0.8026 - 2s/epoch - 32ms/step
# Epoch 50/100
# 53/53 - 2s - loss: 0.1414 - accuracy: 0.8036 - val_loss: 0.1423 - val_accuracy: 0.8081 - 2s/epoch - 32ms/step
# Epoch 51/100
# 53/53 - 2s - loss: 0.1402 - accuracy: 0.8039 - val_loss: 0.1386 - val_accuracy: 0.8029 - 2s/epoch - 30ms/step
# Epoch 52/100
# 53/53 - 2s - loss: 0.1405 - accuracy: 0.8038 - val_loss: 0.1414 - val_accuracy: 0.8083 - 2s/epoch - 33ms/step
# Epoch 53/100
# 53/53 - 2s - loss: 0.1393 - accuracy: 0.8041 - val_loss: 0.1376 - val_accuracy: 0.8031 - 2s/epoch - 33ms/step
# Epoch 54/100
# 53/53 - 2s - loss: 0.1396 - accuracy: 0.8040 - val_loss: 0.1404 - val_accuracy: 0.8084 - 2s/epoch - 31ms/step
# Epoch 55/100
# 53/53 - 2s - loss: 0.1384 - accuracy: 0.8043 - val_loss: 0.1368 - val_accuracy: 0.8033 - 2s/epoch - 30ms/step
# Epoch 56/100
# 53/53 - 2s - loss: 0.1387 - accuracy: 0.8042 - val_loss: 0.1395 - val_accuracy: 0.8086 - 2s/epoch - 30ms/step
# Epoch 57/100
# 53/53 - 2s - loss: 0.1376 - accuracy: 0.8045 - val_loss: 0.1359 - val_accuracy: 0.8036 - 2s/epoch - 32ms/step
# Epoch 58/100
# 53/53 - 2s - loss: 0.1379 - accuracy: 0.8045 - val_loss: 0.1386 - val_accuracy: 0.8087 - 2s/epoch - 32ms/step
# Epoch 59/100
# 53/53 - 2s - loss: 0.1368 - accuracy: 0.8047 - val_loss: 0.1350 - val_accuracy: 0.8039 - 2s/epoch - 31ms/step
# Epoch 60/100
# 53/53 - 2s - loss: 0.1371 - accuracy: 0.8046 - val_loss: 0.1378 - val_accuracy: 0.8088 - 2s/epoch - 33ms/step
# Epoch 61/100
# 53/53 - 2s - loss: 0.1361 - accuracy: 0.8049 - val_loss: 0.1342 - val_accuracy: 0.8040 - 2s/epoch - 33ms/step
# Epoch 62/100
# 53/53 - 2s - loss: 0.1364 - accuracy: 0.8048 - val_loss: 0.1370 - val_accuracy: 0.8090 - 2s/epoch - 32ms/step
# Epoch 63/100
# 53/53 - 2s - loss: 0.1353 - accuracy: 0.8051 - val_loss: 0.1335 - val_accuracy: 0.8042 - 2s/epoch - 32ms/step
# Epoch 64/100
# 53/53 - 2s - loss: 0.1357 - accuracy: 0.8050 - val_loss: 0.1362 - val_accuracy: 0.8091 - 2s/epoch - 30ms/step
# Epoch 65/100
# 53/53 - 2s - loss: 0.1346 - accuracy: 0.8052 - val_loss: 0.1328 - val_accuracy: 0.8044 - 2s/epoch - 32ms/step
# Epoch 66/100
# 53/53 - 2s - loss: 0.1349 - accuracy: 0.8052 - val_loss: 0.1356 - val_accuracy: 0.8092 - 2s/epoch - 31ms/step
# Epoch 67/100
# 53/53 - 2s - loss: 0.1339 - accuracy: 0.8054 - val_loss: 0.1321 - val_accuracy: 0.8045 - 2s/epoch - 32ms/step
# Epoch 68/100
# 53/53 - 2s - loss: 0.1343 - accuracy: 0.8053 - val_loss: 0.1348 - val_accuracy: 0.8094 - 2s/epoch - 32ms/step
# Epoch 69/100
# 53/53 - 2s - loss: 0.1332 - accuracy: 0.8056 - val_loss: 0.1314 - val_accuracy: 0.8047 - 2s/epoch - 33ms/step
# Epoch 70/100
# 53/53 - 2s - loss: 0.1337 - accuracy: 0.8055 - val_loss: 0.1342 - val_accuracy: 0.8095 - 2s/epoch - 34ms/step
# Epoch 71/100
# 53/53 - 2s - loss: 0.1326 - accuracy: 0.8057 - val_loss: 0.1306 - val_accuracy: 0.8049 - 2s/epoch - 30ms/step
# Epoch 72/100
# 53/53 - 2s - loss: 0.1331 - accuracy: 0.8056 - val_loss: 0.1338 - val_accuracy: 0.8096 - 2s/epoch - 30ms/step
# Epoch 73/100
# 53/53 - 2s - loss: 0.1319 - accuracy: 0.8059 - val_loss: 0.1300 - val_accuracy: 0.8053 - 2s/epoch - 32ms/step
# Epoch 74/100
# 53/53 - 2s - loss: 0.1323 - accuracy: 0.8058 - val_loss: 0.1332 - val_accuracy: 0.8095 - 2s/epoch - 32ms/step
# Epoch 75/100
# 53/53 - 2s - loss: 0.1316 - accuracy: 0.8059 - val_loss: 0.1298 - val_accuracy: 0.8048 - 2s/epoch - 38ms/step
# Epoch 76/100
# 53/53 - 2s - loss: 0.1321 - accuracy: 0.8059 - val_loss: 0.1324 - val_accuracy: 0.8098 - 2s/epoch - 32ms/step
# Epoch 77/100
# 53/53 - 2s - loss: 0.1308 - accuracy: 0.8062 - val_loss: 0.1290 - val_accuracy: 0.8054 - 2s/epoch - 33ms/step
# Epoch 78/100
# 53/53 - 2s - loss: 0.1311 - accuracy: 0.8061 - val_loss: 0.1319 - val_accuracy: 0.8097 - 2s/epoch - 33ms/step
# Epoch 79/100
# 53/53 - 2s - loss: 0.1306 - accuracy: 0.8062 - val_loss: 0.1288 - val_accuracy: 0.8050 - 2s/epoch - 30ms/step
# Epoch 80/100
# 53/53 - 2s - loss: 0.1310 - accuracy: 0.8061 - val_loss: 0.1314 - val_accuracy: 0.8100 - 2s/epoch - 32ms/step
# Epoch 81/100
# 53/53 - 2s - loss: 0.1298 - accuracy: 0.8064 - val_loss: 0.1279 - val_accuracy: 0.8055 - 2s/epoch - 32ms/step
# Epoch 82/100
# 53/53 - 2s - loss: 0.1300 - accuracy: 0.8064 - val_loss: 0.1308 - val_accuracy: 0.8098 - 2s/epoch - 32ms/step
# Epoch 83/100
# 53/53 - 2s - loss: 0.1295 - accuracy: 0.8064 - val_loss: 0.1278 - val_accuracy: 0.8052 - 2s/epoch - 30ms/step
# Epoch 84/100
# 53/53 - 2s - loss: 0.1299 - accuracy: 0.8064 - val_loss: 0.1304 - val_accuracy: 0.8101 - 2s/epoch - 31ms/step
# Epoch 85/100
# 53/53 - 2s - loss: 0.1288 - accuracy: 0.8067 - val_loss: 0.1271 - val_accuracy: 0.8056 - 2s/epoch - 32ms/step
# Epoch 86/100
# 53/53 - 2s - loss: 0.1290 - accuracy: 0.8066 - val_loss: 0.1296 - val_accuracy: 0.8098 - 2s/epoch - 32ms/step
# Epoch 87/100
# 53/53 - 2s - loss: 0.1285 - accuracy: 0.8067 - val_loss: 0.1266 - val_accuracy: 0.8055 - 2s/epoch - 31ms/step
# Epoch 88/100
# 53/53 - 2s - loss: 0.1290 - accuracy: 0.8066 - val_loss: 0.1294 - val_accuracy: 0.8103 - 2s/epoch - 32ms/step
# Epoch 89/100
# 53/53 - 2s - loss: 0.1278 - accuracy: 0.8069 - val_loss: 0.1259 - val_accuracy: 0.8064 - 2s/epoch - 30ms/step
# Epoch 90/100
# 53/53 - 2s - loss: 0.1281 - accuracy: 0.8067 - val_loss: 0.1296 - val_accuracy: 0.8103 - 2s/epoch - 31ms/step
# Epoch 91/100
# 53/53 - 2s - loss: 0.1280 - accuracy: 0.8069 - val_loss: 0.1259 - val_accuracy: 0.8061 - 2s/epoch - 32ms/step
# Epoch 92/100
# 53/53 - 2s - loss: 0.1278 - accuracy: 0.8069 - val_loss: 0.1277 - val_accuracy: 0.8103 - 2s/epoch - 32ms/step
# Epoch 93/100
# 53/53 - 2s - loss: 0.1273 - accuracy: 0.8070 - val_loss: 0.1251 - val_accuracy: 0.8062 - 2s/epoch - 33ms/step
# Epoch 94/100
# 53/53 - 2s - loss: 0.1272 - accuracy: 0.8070 - val_loss: 0.1279 - val_accuracy: 0.8101 - 2s/epoch - 32ms/step
# Epoch 95/100
# 53/53 - 2s - loss: 0.1268 - accuracy: 0.8071 - val_loss: 0.1250 - val_accuracy: 0.8060 - 2s/epoch - 33ms/step
# Epoch 96/100
# 53/53 - 2s - loss: 0.1272 - accuracy: 0.8071 - val_loss: 0.1277 - val_accuracy: 0.8105 - 2s/epoch - 30ms/step
# Epoch 97/100
# 53/53 - 2s - loss: 0.1262 - accuracy: 0.8073 - val_loss: 0.1245 - val_accuracy: 0.8063 - 2s/epoch - 32ms/step
# Epoch 98/100
# 53/53 - 2s - loss: 0.1261 - accuracy: 0.8071 - val_loss: 0.1285 - val_accuracy: 0.8106 - 2s/epoch - 31ms/step
# Epoch 99/100
# 53/53 - 2s - loss: 0.1266 - accuracy: 0.8073 - val_loss: 0.1243 - val_accuracy: 0.8067 - 2s/epoch - 32ms/step
# Epoch 100/100
# 53/53 - 2s - loss: 0.1262 - accuracy: 0.8072 - val_loss: 0.1262 - val_accuracy: 0.8105 - 2s/epoch - 32ms/step
# Training Took 203.48005938529968 Secs

# %% [markdown]
# Passing image to Encoder

# %%
encoded_imgs = ae_conv_encoder.predict(x_test)
#encoded_imgs = ae_conv_encoder.predict(x_train[0:100])
print (encoded_imgs.shape)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 64)

# %% [markdown]
# Passing Compressed image Features to Decoder

# %%
#decoded_imgs = ae_conv_decoder.predict(encoded_imgs)
decoded_imgs = ae_conv_decoder.predict(encoded_imgs)

deoceded_images = Ae_Conv.predict(x_test)
print("Recreated image Representation of Shape {} using Decoder and reduced Image representation of shape {}".format (decoded_imgs.shape,
                                                                                                                      encoded_imgs.shape))
n = 10  # how many digits we will display
k= 12 # multiplier
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i*k].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i*k].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# Recreated image Representation of Shape (10000, 28, 28, 1) using Decoder and reduced Image representation of shape (10000, 64)

# %%
deoceded_images = Ae_Conv.predict(x_test)
print("Recreated image Representation of Shape {} using Decoder and reduced Image representation of shape {}".format (deoceded_images.shape,
                                                                                                                      deoceded_images.shape))
n = 10  # how many digits we will display
k= 12 # multiplier
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i*k].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(deoceded_images[i*k].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Recreated image Representation of Shape (10000, 28, 28, 1) using Decoder and reduced Image representation of shape (10000, 28, 28, 1)

# %%
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# Adding Noise to the Data

# %%
# Create Noisy Data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
print(x_train_noisy.shape,x_test_noisy.shape )
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %% [markdown]
# Displaying the Noisy Data

# %%
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_train_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()

# %% [markdown]
# Architecture for Denoising Auto Encoder

# %%
input_layer_cnv = Input(shape = (28,28,1))
ae_cnv_en = Conv2D (32, (3,3), activation = "relu", padding = "same", kernel_initializer="he_normal")(input_layer_cnv)
ae_cnv_en = MaxPooling2D ((2,2), padding="same")(ae_cnv_en)

ae_cnv_en = Conv2D (32, (3,3), activation = "relu", padding = "same")(ae_cnv_en)
ae_cnv_en = MaxPooling2D ((2,2), padding="same")(ae_cnv_en)

ae_cnv_en = Conv2D (4, (3,3), activation = "relu", padding = "same")(ae_cnv_en)
ae_cnv_en = MaxPooling2D ((2,2), padding="same")(ae_cnv_en)

ae_cnv_en = Flatten(name = "bot")(ae_cnv_en)

ae_cnv_de = Reshape((4,4,4), input_shape= (64,), name= "botnext0")(ae_cnv_en)

ae_cnv_de = Conv2D (4, (3,3), activation = "relu", padding = "same",name= "botnext1")(ae_cnv_de)
ae_cnv_de = UpSampling2D ((2,2),name= "botnext2")(ae_cnv_de)

ae_cnv_de = Conv2D (32, (3,3), activation = "relu", padding = "same", name= "botnext3")(ae_cnv_de)
ae_cnv_de = UpSampling2D ((2,2), name= "botnext4")(ae_cnv_de)

ae_cnv_de = Conv2D (32, (3,3), activation = "relu", padding = "valid",name= "botnext5")(ae_cnv_de)
ae_cnv_de = UpSampling2D ((2,2), name= "botnext6")(ae_cnv_de)

ae_cnv_de = Conv2D (1, (3,3), activation = "sigmoid", padding = "same",name = "botnext7")(ae_cnv_de)
Ae_Conv_denoise = Model (inputs = input_layer_cnv, outputs = ae_cnv_de)

#Ae_Conv.compile(optimizer=tf.keras.optimizers.SGD(0.09,clipvalue=2.5), loss='binary_crossentropy', metrics = ["accuracy"])

Ae_Conv_denoise.compile(optimizer=tf.keras.optimizers.Adadelta(0.1,clipvalue=2), loss='binary_crossentropy', metrics = ["accuracy"])
Ae_Conv_denoise.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 4)           1156
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 4)           0
#  g2D)
#
#  bot (Flatten)               (None, 64)                0
#
#  botnext0 (Reshape)          (None, 4, 4, 4)           0
#
#  botnext1 (Conv2D)           (None, 4, 4, 4)           148
#
#  botnext2 (UpSampling2D)     (None, 8, 8, 4)           0
#
#  botnext3 (Conv2D)           (None, 8, 8, 32)          1184
#
#  botnext4 (UpSampling2D)     (None, 16, 16, 32)        0
#
#  botnext5 (Conv2D)           (None, 14, 14, 32)        9248
#
#  botnext6 (UpSampling2D)     (None, 28, 28, 32)        0
#
#  botnext7 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 21593 (84.35 KB)
# Trainable params: 21593 (84.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Encoder

# %%
ae_conv_dns_encoder = Model (inputs = input_layer_cnv,outputs = Ae_Conv_denoise.get_layer("bot").output, name = "Conv_AE_dns_encoder")
ae_conv_dns_encoder.summary()
# Out:
# Model: "Conv_AE_dns_encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 4)           1156
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 4)           0
#  g2D)
#
#  bot (Flatten)               (None, 64)                0
#
# =================================================================
# Total params: 10724 (41.89 KB)
# Trainable params: 10724 (41.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Decoder

# %%
encode_inp_cnv = Input(shape = (64,))
tmp_dec = Ae_Conv_denoise.get_layer("botnext0")(encode_inp_cnv)
for i in range(1,8):
  st = "botnext{}".format(i)
  tmp_dec = Ae_Conv_denoise.get_layer(st)(tmp_dec)

ae_conv_dns_decoder = Model(inputs = encode_inp_cnv,outputs = tmp_dec, name= "Conv_AE_dns_decoder")
ae_conv_dns_decoder.summary()
# Out:
# Model: "Conv_AE_dns_decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 64)]              0
#
#  botnext0 (Reshape)          (None, 4, 4, 4)           0
#
#  botnext1 (Conv2D)           (None, 4, 4, 4)           148
#
#  botnext2 (UpSampling2D)     (None, 8, 8, 4)           0
#
#  botnext3 (Conv2D)           (None, 8, 8, 32)          1184
#
#  botnext4 (UpSampling2D)     (None, 16, 16, 32)        0
#
#  botnext5 (Conv2D)           (None, 14, 14, 32)        9248
#
#  botnext6 (UpSampling2D)     (None, 28, 28, 32)        0
#
#  botnext7 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 10869 (42.46 KB)
# Trainable params: 10869 (42.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Training the Denoising Auto Encoder

# %%
from time import time
tic = time()
Ae_Conv_denoise.fit(x_train_noisy, x_train,
                epochs=100,
                verbose=2,
                batch_size=256,
                shuffle=False, validation_split = 0.1)
                #validation_data=(x_test, x_test))
toc = time()
print("Training Took {} Secs".format(toc-tic))
# Out:
# Epoch 1/100
# 211/211 - 5s - loss: 0.3250 - accuracy: 0.7936 - val_loss: 0.2583 - val_accuracy: 0.8006 - 5s/epoch - 24ms/step
# Epoch 2/100
# 211/211 - 2s - loss: 0.2522 - accuracy: 0.7943 - val_loss: 0.2422 - val_accuracy: 0.8019 - 2s/epoch - 9ms/step
# Epoch 3/100
# 211/211 - 2s - loss: 0.2391 - accuracy: 0.7934 - val_loss: 0.2324 - val_accuracy: 0.7996 - 2s/epoch - 9ms/step
# Epoch 4/100
# 211/211 - 2s - loss: 0.2296 - accuracy: 0.7933 - val_loss: 0.2256 - val_accuracy: 0.7979 - 2s/epoch - 10ms/step
# Epoch 5/100
# 211/211 - 2s - loss: 0.2232 - accuracy: 0.7931 - val_loss: 0.2205 - val_accuracy: 0.7969 - 2s/epoch - 10ms/step
# Epoch 6/100
# 211/211 - 2s - loss: 0.2184 - accuracy: 0.7930 - val_loss: 0.2161 - val_accuracy: 0.7961 - 2s/epoch - 9ms/step
# Epoch 7/100
# 211/211 - 2s - loss: 0.2143 - accuracy: 0.7932 - val_loss: 0.2123 - val_accuracy: 0.7954 - 2s/epoch - 9ms/step
# Epoch 8/100
# 211/211 - 2s - loss: 0.2107 - accuracy: 0.7936 - val_loss: 0.2089 - val_accuracy: 0.7948 - 2s/epoch - 9ms/step
# Epoch 9/100
# 211/211 - 2s - loss: 0.2076 - accuracy: 0.7939 - val_loss: 0.2058 - val_accuracy: 0.7946 - 2s/epoch - 9ms/step
# Epoch 10/100
# 211/211 - 2s - loss: 0.2048 - accuracy: 0.7943 - val_loss: 0.2030 - val_accuracy: 0.7948 - 2s/epoch - 10ms/step
# Epoch 11/100
# 211/211 - 2s - loss: 0.2020 - accuracy: 0.7947 - val_loss: 0.2003 - val_accuracy: 0.7949 - 2s/epoch - 10ms/step
# Epoch 12/100
# 211/211 - 2s - loss: 0.1994 - accuracy: 0.7951 - val_loss: 0.1977 - val_accuracy: 0.7952 - 2s/epoch - 9ms/step
# Epoch 13/100
# 211/211 - 2s - loss: 0.1967 - accuracy: 0.7956 - val_loss: 0.1952 - val_accuracy: 0.7956 - 2s/epoch - 9ms/step
# Epoch 14/100
# 211/211 - 2s - loss: 0.1943 - accuracy: 0.7959 - val_loss: 0.1930 - val_accuracy: 0.7957 - 2s/epoch - 9ms/step
# Epoch 15/100
# 211/211 - 2s - loss: 0.1922 - accuracy: 0.7962 - val_loss: 0.1910 - val_accuracy: 0.7958 - 2s/epoch - 9ms/step
# Epoch 16/100
# 211/211 - 2s - loss: 0.1904 - accuracy: 0.7964 - val_loss: 0.1891 - val_accuracy: 0.7959 - 2s/epoch - 9ms/step
# Epoch 17/100
# 211/211 - 2s - loss: 0.1887 - accuracy: 0.7966 - val_loss: 0.1873 - val_accuracy: 0.7962 - 2s/epoch - 10ms/step
# Epoch 18/100
# 211/211 - 2s - loss: 0.1870 - accuracy: 0.7969 - val_loss: 0.1856 - val_accuracy: 0.7964 - 2s/epoch - 10ms/step
# Epoch 19/100
# 211/211 - 2s - loss: 0.1855 - accuracy: 0.7971 - val_loss: 0.1840 - val_accuracy: 0.7968 - 2s/epoch - 9ms/step
# Epoch 20/100
# 211/211 - 2s - loss: 0.1839 - accuracy: 0.7974 - val_loss: 0.1825 - val_accuracy: 0.7970 - 2s/epoch - 9ms/step
# Epoch 21/100
# 211/211 - 2s - loss: 0.1825 - accuracy: 0.7977 - val_loss: 0.1811 - val_accuracy: 0.7974 - 2s/epoch - 9ms/step
# Epoch 22/100
# 211/211 - 2s - loss: 0.1812 - accuracy: 0.7980 - val_loss: 0.1798 - val_accuracy: 0.7976 - 2s/epoch - 9ms/step
# Epoch 23/100
# 211/211 - 2s - loss: 0.1799 - accuracy: 0.7982 - val_loss: 0.1786 - val_accuracy: 0.7978 - 2s/epoch - 9ms/step
# Epoch 24/100
# 211/211 - 2s - loss: 0.1787 - accuracy: 0.7984 - val_loss: 0.1774 - val_accuracy: 0.7980 - 2s/epoch - 10ms/step
# Epoch 25/100
# 211/211 - 2s - loss: 0.1775 - accuracy: 0.7987 - val_loss: 0.1763 - val_accuracy: 0.7982 - 2s/epoch - 10ms/step
# Epoch 26/100
# 211/211 - 2s - loss: 0.1764 - accuracy: 0.7989 - val_loss: 0.1752 - val_accuracy: 0.7984 - 2s/epoch - 9ms/step
# Epoch 27/100
# 211/211 - 2s - loss: 0.1754 - accuracy: 0.7991 - val_loss: 0.1742 - val_accuracy: 0.7986 - 2s/epoch - 9ms/step
# Epoch 28/100
# 211/211 - 2s - loss: 0.1744 - accuracy: 0.7993 - val_loss: 0.1733 - val_accuracy: 0.7987 - 2s/epoch - 10ms/step
# Epoch 29/100
# 211/211 - 2s - loss: 0.1735 - accuracy: 0.7995 - val_loss: 0.1724 - val_accuracy: 0.7988 - 2s/epoch - 11ms/step
# Epoch 30/100
# 211/211 - 2s - loss: 0.1726 - accuracy: 0.7997 - val_loss: 0.1716 - val_accuracy: 0.7989 - 2s/epoch - 10ms/step
# Epoch 31/100
# 211/211 - 2s - loss: 0.1717 - accuracy: 0.7999 - val_loss: 0.1708 - val_accuracy: 0.7992 - 2s/epoch - 11ms/step
# Epoch 32/100
# 211/211 - 2s - loss: 0.1709 - accuracy: 0.8001 - val_loss: 0.1700 - val_accuracy: 0.7992 - 2s/epoch - 12ms/step
# Epoch 33/100
# 211/211 - 2s - loss: 0.1702 - accuracy: 0.8002 - val_loss: 0.1693 - val_accuracy: 0.7995 - 2s/epoch - 10ms/step
# Epoch 34/100
# 211/211 - 2s - loss: 0.1694 - accuracy: 0.8004 - val_loss: 0.1685 - val_accuracy: 0.7996 - 2s/epoch - 9ms/step
# Epoch 35/100
# 211/211 - 2s - loss: 0.1686 - accuracy: 0.8006 - val_loss: 0.1679 - val_accuracy: 0.7998 - 2s/epoch - 9ms/step
# Epoch 36/100
# 211/211 - 2s - loss: 0.1679 - accuracy: 0.8007 - val_loss: 0.1672 - val_accuracy: 0.7998 - 2s/epoch - 9ms/step
# Epoch 37/100
# 211/211 - 2s - loss: 0.1672 - accuracy: 0.8009 - val_loss: 0.1666 - val_accuracy: 0.8000 - 2s/epoch - 9ms/step
# Epoch 38/100
# 211/211 - 2s - loss: 0.1666 - accuracy: 0.8010 - val_loss: 0.1659 - val_accuracy: 0.8001 - 2s/epoch - 10ms/step
# Epoch 39/100
# 211/211 - 2s - loss: 0.1660 - accuracy: 0.8011 - val_loss: 0.1653 - val_accuracy: 0.8002 - 2s/epoch - 10ms/step
# Epoch 40/100
# 211/211 - 2s - loss: 0.1654 - accuracy: 0.8013 - val_loss: 0.1647 - val_accuracy: 0.8003 - 2s/epoch - 9ms/step
# Epoch 41/100
# 211/211 - 2s - loss: 0.1648 - accuracy: 0.8014 - val_loss: 0.1641 - val_accuracy: 0.8004 - 2s/epoch - 9ms/step
# Epoch 42/100
# 211/211 - 2s - loss: 0.1642 - accuracy: 0.8015 - val_loss: 0.1636 - val_accuracy: 0.8005 - 2s/epoch - 11ms/step
# Epoch 43/100
# 211/211 - 2s - loss: 0.1636 - accuracy: 0.8016 - val_loss: 0.1630 - val_accuracy: 0.8006 - 2s/epoch - 9ms/step
# Epoch 44/100
# 211/211 - 2s - loss: 0.1631 - accuracy: 0.8017 - val_loss: 0.1625 - val_accuracy: 0.8008 - 2s/epoch - 11ms/step
# Epoch 45/100
# 211/211 - 3s - loss: 0.1625 - accuracy: 0.8018 - val_loss: 0.1620 - val_accuracy: 0.8009 - 3s/epoch - 13ms/step
# Epoch 46/100
# 211/211 - 2s - loss: 0.1620 - accuracy: 0.8019 - val_loss: 0.1615 - val_accuracy: 0.8010 - 2s/epoch - 9ms/step
# Epoch 47/100
# 211/211 - 2s - loss: 0.1615 - accuracy: 0.8020 - val_loss: 0.1610 - val_accuracy: 0.8011 - 2s/epoch - 9ms/step
# Epoch 48/100
# 211/211 - 2s - loss: 0.1610 - accuracy: 0.8021 - val_loss: 0.1605 - val_accuracy: 0.8013 - 2s/epoch - 9ms/step
# Epoch 49/100
# 211/211 - 2s - loss: 0.1605 - accuracy: 0.8022 - val_loss: 0.1600 - val_accuracy: 0.8014 - 2s/epoch - 9ms/step
# Epoch 50/100
# 211/211 - 2s - loss: 0.1600 - accuracy: 0.8024 - val_loss: 0.1595 - val_accuracy: 0.8015 - 2s/epoch - 9ms/step
# Epoch 51/100
# 211/211 - 2s - loss: 0.1596 - accuracy: 0.8024 - val_loss: 0.1591 - val_accuracy: 0.8017 - 2s/epoch - 10ms/step
# Epoch 52/100
# 211/211 - 2s - loss: 0.1591 - accuracy: 0.8025 - val_loss: 0.1586 - val_accuracy: 0.8018 - 2s/epoch - 10ms/step
# Epoch 53/100
# 211/211 - 2s - loss: 0.1587 - accuracy: 0.8026 - val_loss: 0.1582 - val_accuracy: 0.8019 - 2s/epoch - 9ms/step
# Epoch 54/100
# 211/211 - 2s - loss: 0.1583 - accuracy: 0.8027 - val_loss: 0.1578 - val_accuracy: 0.8020 - 2s/epoch - 9ms/step
# Epoch 55/100
# 211/211 - 2s - loss: 0.1579 - accuracy: 0.8028 - val_loss: 0.1574 - val_accuracy: 0.8021 - 2s/epoch - 9ms/step
# Epoch 56/100
# 211/211 - 2s - loss: 0.1575 - accuracy: 0.8029 - val_loss: 0.1570 - val_accuracy: 0.8022 - 2s/epoch - 9ms/step
# Epoch 57/100
# 211/211 - 2s - loss: 0.1571 - accuracy: 0.8030 - val_loss: 0.1566 - val_accuracy: 0.8023 - 2s/epoch - 9ms/step
# Epoch 58/100
# 211/211 - 2s - loss: 0.1567 - accuracy: 0.8031 - val_loss: 0.1562 - val_accuracy: 0.8023 - 2s/epoch - 10ms/step
# Epoch 59/100
# 211/211 - 2s - loss: 0.1563 - accuracy: 0.8032 - val_loss: 0.1558 - val_accuracy: 0.8024 - 2s/epoch - 10ms/step
# Epoch 60/100
# 211/211 - 2s - loss: 0.1559 - accuracy: 0.8032 - val_loss: 0.1554 - val_accuracy: 0.8025 - 2s/epoch - 9ms/step
# Epoch 61/100
# 211/211 - 2s - loss: 0.1555 - accuracy: 0.8033 - val_loss: 0.1550 - val_accuracy: 0.8026 - 2s/epoch - 9ms/step
# Epoch 62/100
# 211/211 - 2s - loss: 0.1551 - accuracy: 0.8034 - val_loss: 0.1547 - val_accuracy: 0.8026 - 2s/epoch - 9ms/step
# Epoch 63/100
# 211/211 - 2s - loss: 0.1547 - accuracy: 0.8035 - val_loss: 0.1543 - val_accuracy: 0.8027 - 2s/epoch - 9ms/step
# Epoch 64/100
# 211/211 - 2s - loss: 0.1544 - accuracy: 0.8035 - val_loss: 0.1540 - val_accuracy: 0.8027 - 2s/epoch - 9ms/step
# Epoch 65/100
# 211/211 - 2s - loss: 0.1540 - accuracy: 0.8036 - val_loss: 0.1536 - val_accuracy: 0.8028 - 2s/epoch - 11ms/step
# Epoch 66/100
# 211/211 - 2s - loss: 0.1537 - accuracy: 0.8037 - val_loss: 0.1533 - val_accuracy: 0.8029 - 2s/epoch - 10ms/step
# Epoch 67/100
# 211/211 - 2s - loss: 0.1534 - accuracy: 0.8038 - val_loss: 0.1529 - val_accuracy: 0.8030 - 2s/epoch - 9ms/step
# Epoch 68/100
# 211/211 - 2s - loss: 0.1531 - accuracy: 0.8038 - val_loss: 0.1526 - val_accuracy: 0.8030 - 2s/epoch - 9ms/step
# Epoch 69/100
# 211/211 - 2s - loss: 0.1528 - accuracy: 0.8039 - val_loss: 0.1523 - val_accuracy: 0.8030 - 2s/epoch - 9ms/step
# Epoch 70/100
# 211/211 - 2s - loss: 0.1524 - accuracy: 0.8039 - val_loss: 0.1519 - val_accuracy: 0.8031 - 2s/epoch - 10ms/step
# Epoch 71/100
# 211/211 - 2s - loss: 0.1521 - accuracy: 0.8040 - val_loss: 0.1516 - val_accuracy: 0.8032 - 2s/epoch - 10ms/step
# Epoch 72/100
# 211/211 - 2s - loss: 0.1518 - accuracy: 0.8041 - val_loss: 0.1513 - val_accuracy: 0.8033 - 2s/epoch - 10ms/step
# Epoch 73/100
# 211/211 - 2s - loss: 0.1514 - accuracy: 0.8041 - val_loss: 0.1510 - val_accuracy: 0.8033 - 2s/epoch - 9ms/step
# Epoch 74/100
# 211/211 - 2s - loss: 0.1511 - accuracy: 0.8042 - val_loss: 0.1507 - val_accuracy: 0.8034 - 2s/epoch - 9ms/step
# Epoch 75/100
# 211/211 - 2s - loss: 0.1509 - accuracy: 0.8043 - val_loss: 0.1504 - val_accuracy: 0.8035 - 2s/epoch - 9ms/step
# Epoch 76/100
# 211/211 - 2s - loss: 0.1505 - accuracy: 0.8043 - val_loss: 0.1501 - val_accuracy: 0.8035 - 2s/epoch - 9ms/step
# Epoch 77/100
# 211/211 - 2s - loss: 0.1503 - accuracy: 0.8044 - val_loss: 0.1498 - val_accuracy: 0.8036 - 2s/epoch - 9ms/step
# Epoch 78/100
# 211/211 - 2s - loss: 0.1500 - accuracy: 0.8044 - val_loss: 0.1495 - val_accuracy: 0.8037 - 2s/epoch - 10ms/step
# Epoch 79/100
# 211/211 - 2s - loss: 0.1497 - accuracy: 0.8045 - val_loss: 0.1492 - val_accuracy: 0.8037 - 2s/epoch - 10ms/step
# Epoch 80/100
# 211/211 - 2s - loss: 0.1494 - accuracy: 0.8046 - val_loss: 0.1489 - val_accuracy: 0.8038 - 2s/epoch - 10ms/step
# Epoch 81/100
# 211/211 - 2s - loss: 0.1491 - accuracy: 0.8046 - val_loss: 0.1486 - val_accuracy: 0.8038 - 2s/epoch - 9ms/step
# Epoch 82/100
# 211/211 - 2s - loss: 0.1489 - accuracy: 0.8047 - val_loss: 0.1483 - val_accuracy: 0.8039 - 2s/epoch - 9ms/step
# Epoch 83/100
# 211/211 - 2s - loss: 0.1486 - accuracy: 0.8047 - val_loss: 0.1481 - val_accuracy: 0.8039 - 2s/epoch - 9ms/step
# Epoch 84/100
# 211/211 - 2s - loss: 0.1483 - accuracy: 0.8048 - val_loss: 0.1478 - val_accuracy: 0.8040 - 2s/epoch - 9ms/step
# Epoch 85/100
# 211/211 - 2s - loss: 0.1481 - accuracy: 0.8048 - val_loss: 0.1476 - val_accuracy: 0.8041 - 2s/epoch - 10ms/step
# Epoch 86/100
# 211/211 - 2s - loss: 0.1478 - accuracy: 0.8049 - val_loss: 0.1473 - val_accuracy: 0.8041 - 2s/epoch - 10ms/step
# Epoch 87/100
# 211/211 - 2s - loss: 0.1475 - accuracy: 0.8049 - val_loss: 0.1471 - val_accuracy: 0.8041 - 2s/epoch - 9ms/step
# Epoch 88/100
# 211/211 - 2s - loss: 0.1473 - accuracy: 0.8050 - val_loss: 0.1468 - val_accuracy: 0.8042 - 2s/epoch - 9ms/step
# Epoch 89/100
# 211/211 - 2s - loss: 0.1471 - accuracy: 0.8050 - val_loss: 0.1466 - val_accuracy: 0.8043 - 2s/epoch - 9ms/step
# Epoch 90/100
# 211/211 - 2s - loss: 0.1468 - accuracy: 0.8051 - val_loss: 0.1463 - val_accuracy: 0.8043 - 2s/epoch - 9ms/step
# Epoch 91/100
# 211/211 - 2s - loss: 0.1466 - accuracy: 0.8051 - val_loss: 0.1461 - val_accuracy: 0.8043 - 2s/epoch - 10ms/step
# Epoch 92/100
# 211/211 - 2s - loss: 0.1463 - accuracy: 0.8052 - val_loss: 0.1459 - val_accuracy: 0.8044 - 2s/epoch - 10ms/step
# Epoch 93/100
# 211/211 - 2s - loss: 0.1461 - accuracy: 0.8052 - val_loss: 0.1456 - val_accuracy: 0.8044 - 2s/epoch - 9ms/step
# Epoch 94/100
# 211/211 - 2s - loss: 0.1459 - accuracy: 0.8053 - val_loss: 0.1454 - val_accuracy: 0.8045 - 2s/epoch - 9ms/step
# Epoch 95/100
# 211/211 - 2s - loss: 0.1456 - accuracy: 0.8053 - val_loss: 0.1452 - val_accuracy: 0.8045 - 2s/epoch - 9ms/step
# Epoch 96/100
# 211/211 - 2s - loss: 0.1454 - accuracy: 0.8053 - val_loss: 0.1450 - val_accuracy: 0.8045 - 2s/epoch - 9ms/step
# Epoch 97/100
# 211/211 - 2s - loss: 0.1452 - accuracy: 0.8054 - val_loss: 0.1448 - val_accuracy: 0.8046 - 2s/epoch - 9ms/step
# Epoch 98/100
# 211/211 - 2s - loss: 0.1450 - accuracy: 0.8054 - val_loss: 0.1446 - val_accuracy: 0.8046 - 2s/epoch - 10ms/step
# Epoch 99/100
# 211/211 - 2s - loss: 0.1448 - accuracy: 0.8055 - val_loss: 0.1444 - val_accuracy: 0.8046 - 2s/epoch - 10ms/step
# Epoch 100/100
# 211/211 - 2s - loss: 0.1446 - accuracy: 0.8055 - val_loss: 0.1442 - val_accuracy: 0.8046 - 2s/epoch - 9ms/step
# Training Took 205.4873435497284 Secs

# %% [markdown]
# Passing images to Encoder

# %%
dns_encoded_imgs = ae_conv_dns_encoder.predict(x_test_noisy)
#encoded_imgs = ae_conv_encoder.predict(x_train[0:100])
print (dns_encoded_imgs.shape)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 64)

# %% [markdown]
# Passing Compressed image Features to Deccoder
